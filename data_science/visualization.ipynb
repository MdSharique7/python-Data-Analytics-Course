# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({
    'state':['UP','AP','MP','Bihar','Rajasthan','Maharastra'],
    'population':[800,300,600,400,500,600],
    'rainfall':[39,65,78,40,10,20],
    'temperature':[34,26,22,25,30,32],
    'status': ['A','B','A','A','B','A']
})

# %%
data
# Out:
#         state  population  rainfall  temperature status
# 0          UP         800        39           34      A
# 1          AP         300        65           26      B
# 2          MP         600        78           22      A
# 3       Bihar         400        40           25      A
# 4   Rajasthan         500        10           30      B
# 5  Maharastra         600        20           32      A

# %%
data['state']
# Out:
# 0            UP
# 1            AP
# 2            MP
# 3         Bihar
# 4     Rajasthan
# 5    Maharastra
# Name: state, dtype: object

# %%
data[['state','temperature']]
# Out:
#         state  temperature
# 0          UP           34
# 1          AP           26
# 2          MP           22
# 3       Bihar           25
# 4   Rajasthan           30
# 5  Maharastra           32

# %%
data
# Out:
#         state  population  rainfall  temperature status
# 0          UP         800        39           34      A
# 1          AP         300        65           26      B
# 2          MP         600        78           22      A
# 3       Bihar         400        40           25      A
# 4   Rajasthan         500        10           30      B
# 5  Maharastra         600        20           32      A

# %% [markdown]
# visualization
# - line plot(time series,trend,seasonability,cyclicity,nois,outliers,misssing values,etc)
# - area plot
# - bar plot
# - histogram
# - pie chart
# - box plot
# - scatter plot
# - bubble plot

# %%
data['population'].plot(figsize=(12,4))
# Out:
# <AxesSubplot: >

# %%
data['population'].plot(figsize=(12,4),style='sr--',markersize=15,linewidth = 2,title = 'population of states')
data['population'].plot(figsize=(12,4),style ='sr--',
markersize = 15,linewidth =2,
title='population of states',
xlabel = 'states',
ylabel = 'population')
plt.xticks(data.index,data['state'],rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x1c0f9fa68b0>,
#   <matplotlib.axis.XTick at 0x1c0f9fa6a00>,
#   <matplotlib.axis.XTick at 0x1c0f8e57b50>,
#   <matplotlib.axis.XTick at 0x1c0f8e7c760>,
#   <matplotlib.axis.XTick at 0x1c0f8e81250>,
#   <matplotlib.axis.XTick at 0x1c0f8e7c2b0>],
#  [Text(0, 0, 'UP'),
#   Text(1, 0, 'AP'),
#   Text(2, 0, 'MP'),
#   Text(3, 0, 'Bihar'),
#   Text(4, 0, 'Rajasthan'),
#   Text(5, 0, 'Maharastra')])

# %%
data['rainfall'].plot(kind='area',figsize = (12,4),color='red',alpha=.5,title='Rainfall in states')
data['rainfall'].plot(style='ok-',markerfacecolor='black')
plt.xticks(data.index,data['state'])
plt.show()

# %%
data['rainfall'].plot(kind='area',figsize=(12,4),color='red',alpha=.1,title='Rainfall in states')
data['rainfall'].plot(style='ok-',markerfacecolor='black')
plt.xticks(data.index,data['state'])
plt.show()

# %%
data['rainfall'].plot(kind='bar',color='green',alpha=.5)
plt.ylim(0,100)
for i in range(len(data['rainfall'])):
    plt.text(i,data['rainfall'][i],data['rainfall'][i],ha='center',va='bottom')

# %%
graph = data['rainfall'].plot(kind='bar',color='green',alpha=.5)
plt.ylim(0,100)
graph.bar_label(graph.containers[0],label_type='edge')
plt.show()

# %%
ax = data[['temperature','rainfall']].plot(kind='bar',figsize=(12,4),width=.8,color=['red','blue'],alpha=.8)
ax.set_xticklabels(data['state'])
ax.bar_label(ax.containers[0],label_type='center',padding=3)
ax.bar_label(ax.containers[0],label_type='center',padding=3,color='white')
plt.show()
